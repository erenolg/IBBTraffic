# %%
import networkx as nx
from utils import get_graph_topology
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
G = get_graph_topology()

# %%
print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
# Out:
# Number of nodes: 2451
# Number of edges: 3668

# %%
# this file belongs to Jan 2023
traffic_feats = pd.read_csv("./data/202301/dynamic_X.csv")
static_feats = pd.read_csv("./data/202301/static_X.csv")

# since there are 2451 nodes, dataset has 2451 * 24 * 31 rows (nodes, hours in a day, days in Jan)
traffic_feats.shape
# Out:
# (1823544, 6)

# %%
# average speed change in a sensor during 96 hours
plt.plot(traffic_feats.loc[traffic_feats["NODE_ID"]==0]["AVERAGE_SPEED"][48:144].values);

# %%
static_feats.head()
# Out:
#    NODE_ID  district  continent  population_density  freeway
# 0        0         0          0            0.067690        1
# 1        1         1          0            0.573745        0
# 2        2         2          0            0.042436        0
# 3        3         3          0            0.307425        1
# 4        4         4          0            0.000519        0
